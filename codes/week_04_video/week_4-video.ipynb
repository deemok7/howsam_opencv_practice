# %% [markdown]
# # <font color='#FFE15D'>**Week 4: Video**</font> 🎞️

# %% [markdown]
# ## <span style="font-size: 0.9em;">🟥</span> **Import**

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

import time

# %%
cv2.__version__
# Out:
# '4.11.0'

# %% [markdown]
# ## <span style="font-size: 0.9em;">🟥</span> **Section 1: What is Video?**

# %%
cv2.VideoCapture?
# Out:
# Init signature: cv2.VideoCapture(self, /, *args, **kwargs)
# Docstring:      <no docstring>
# File:           d:\venv\venv_general_312\lib\site-packages\cv2\__init__.py
# Type:           type
# Subclasses:

# %% [markdown]
# ### <span style="font-size: 0.9em;">🟧</span> **Capture video from a video file**

# %% [markdown]
# #### <span style="font-size: 0.9em;">🟨</span> **Get a frame**

# %%
cap = cv2.VideoCapture("video/bouncing-ball-25fps.mp4")
cap
# Out:
# < cv2.VideoCapture 00000252EC513CF0>

# %%
cap.isOpened()
# Out:
# True

# %%
ret, frame = cap.read()
ret, frame.shape
# Out:
# (True, (1080, 1920, 3))

# %%
ret, frame
# Out:
# (True,
#  array([[[63, 64, 74],
#          [63, 64, 74],
#          [63, 64, 74],
#          ...,
#          [59, 65, 74],
#          [59, 65, 74],
#          [59, 65, 74]],
#
#         [[63, 64, 74],
#          [63, 64, 74],
#          [63, 64, 74],
#          ...,
#          [59, 65, 74],
#          [59, 65, 74],
#          [59, 65, 74]],
#
#         [[63, 64, 74],
#          [63, 64, 74],
#          [63, 64, 74],
#          ...,
#          [59, 65, 74],
#          [59, 65, 74],
#          [59, 65, 74]],
#
#         ...,
#
#         [[59, 65, 74],
#          [59, 65, 74],
#          [59, 65, 74],
#          ...,
#          [61, 64, 75],
#          [61, 64, 75],
#          [61, 64, 75]],
#
#         [[63, 65, 72],
#          [63, 65, 72],
#          [63, 65, 72],
#          ...,
#          [63, 65, 72],
#          [63, 65, 72],
#          [63, 65, 72]],
#
#         [[63, 65, 72],
#          [63, 65, 72],
#          [63, 65, 72],
#          ...,
#          [63, 65, 72],
# ...

# %%
cv2.imshow("Frame", frame)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
cap.release()

# %% [markdown]
# #### <span style="font-size: 0.9em;">🟨</span> **Get all frames**

# %%
cap = cv2.VideoCapture("video/bouncing-ball-25fps.mp4")

# for i in range(10000):
# while True:
while cap.isOpened():
    # start = time.time()
    ret, frame = cap.read()
    # finish = time.time()
    # print((finish - start)*1000)

    if not ret:
        break
        
    # start = time.time()
    cv2.imshow("Frame", frame)
    # finish = time.time()
    # print((finish - start)*1000)

    # start = time.time()
    key = cv2.waitKey(1000)
    if key == ord("q"):
        break
    # finish = time.time()
    # print((finish - start)*1000)
    
cv2.destroyAllWindows()
cap.release()

# %%
cap = cv2.VideoCapture("video/teqball.mp4")

while cap.isOpened():
    ret, frame = cap.read()

    if not ret:
        break
        
    cv2.imshow("Frame", frame)

    key = cv2.waitKey(500)
    if key == ord("q"):
        break
    
cv2.destroyAllWindows()
cap.release()

# %% [markdown]
# ### <span style="font-size: 0.9em;">🟧</span> **Capture video from a webcam**

# %%
cap = cv2.VideoCapture(0)

while cap.isOpened():
    ret, frame = cap.read()

    if not ret:
        break
        
    cv2.imshow("Frame", frame)
    
    key = cv2.waitKey(1)
    if key == ord("q"):
        break
    
cv2.destroyAllWindows()
cap.release()

# %% [markdown]
# ### <span style="font-size: 0.9em;">🟧</span> **Get & Set video properties**

# %%
cap = cv2.VideoCapture(0)

# %%
cap.
# Out:
#   Cell In[14], line 1
#     cap.
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### <span style="font-size: 0.9em;">🟨</span> **`.get()`**

# %%
cap.get(cv2.CAP_PROP_FPS)
# Out:
# 30.0

# %%
cap.get(cv2.CAP_PROP_FRAME_COUNT)
# Out:
# -1.0

# %%
cap.get(cv2.CAP_PROP_FRAME_HEIGHT), cap.get(cv2.CAP_PROP_FRAME_WIDTH)
# Out:
# (480.0, 640.0)

# %%
cap.get(cv2.CAP_PROP_POS_MSEC), cap.get(cv2.CAP_PROP_POS_FRAMES)
# Out:
# (0.0, 0.0)

# %%
cap = cv2.VideoCapture("video/teqball.mp4")

print(f"Height: {cap.get(cv2.CAP_PROP_FRAME_HEIGHT)}, Width: {cap.get(cv2.CAP_PROP_FRAME_WIDTH)}")
print(f"Frame Count: {cap.get(cv2.CAP_PROP_FRAME_COUNT)}")
print(f"FPS: {cap.get(cv2.CAP_PROP_FPS)}")


while cap.isOpened():
    ret, frame = cap.read()

    if not ret:
        break
        
    cv2.imshow("Frame", frame)

    key = cv2.waitKey(500)
    if key == ord("q"):
        break

    print(f'Time: {cap.get(cv2.CAP_PROP_POS_MSEC)}, NFrames: {cap.get(cv2.CAP_PROP_POS_FRAMES)}')
    
cv2.destroyAllWindows()
cap.release()
# Out:
# Height: 720.0, Width: 1280.0
# Frame Count: 578.0
# FPS: 25.0
# Time: 0.0, NFrames: 1.0
# Time: 40.0, NFrames: 2.0
# Time: 80.0, NFrames: 3.0
# Time: 120.0, NFrames: 4.0
# Time: 160.0, NFrames: 5.0
# Time: 200.0, NFrames: 6.0
# Time: 240.0, NFrames: 7.0
# Time: 280.0, NFrames: 8.0

# %% [markdown]
# #### <span style="font-size: 0.9em;">🟨</span> **`.set()`**

# %%
cap = cv2.VideoCapture(0)

cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 360)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 360)
# cap.set(cv2.CAP_PROP_BRIGHTNESS, 1)
# cap.set(cv2.CAP_PROP_CONTRAST, 2)

print(f"Height: {cap.get(cv2.CAP_PROP_FRAME_HEIGHT)}, Width: {cap.get(cv2.CAP_PROP_FRAME_WIDTH)}")
print(f"Frame Count: {cap.get(cv2.CAP_PROP_FRAME_COUNT)}")
print(f"FPS: {cap.get(cv2.CAP_PROP_FPS)}")


while cap.isOpened():
    ret, frame = cap.read()

    if not ret:
        break
        
    cv2.imshow("Frame", frame)

    key = cv2.waitKey(1)
    if key == ord("q"):
        break

    print(f'Time: {cap.get(cv2.CAP_PROP_POS_MSEC)}, NFrames: {cap.get(cv2.CAP_PROP_POS_FRAMES)}')
    
cv2.destroyAllWindows()
cap.release()
# Out:
# Height: 340.0, Width: 340.0
# Frame Count: -1.0
# FPS: 30.0
# Time: 83843749.679, NFrames: 0.0
# Time: 83843783.0123, NFrames: 0.0
# Time: 83843816.3457, NFrames: 0.0
# Time: 83843849.679, NFrames: 0.0
# Time: 83843883.0123, NFrames: 0.0
# Time: 83843916.3457, NFrames: 0.0
# Time: 83843949.679, NFrames: 0.0
# Time: 83843983.0123, NFrames: 0.0
# Time: 83844016.3457, NFrames: 0.0
# Time: 83844049.679, NFrames: 0.0
# Time: 83844083.0123, NFrames: 0.0
# Time: 83844116.3457, NFrames: 0.0
# Time: 83844149.679, NFrames: 0.0
# Time: 83844183.0123, NFrames: 0.0
# Time: 83844216.3457, NFrames: 0.0
# Time: 83844249.679, NFrames: 0.0
# Time: 83844283.0123, NFrames: 0.0
# Time: 83844316.3457, NFrames: 0.0
# Time: 83844349.679, NFrames: 0.0
# Time: 83844383.0123, NFrames: 0.0
# Time: 83844416.3457, NFrames: 0.0
# Time: 83844449.679, NFrames: 0.0
# Time: 83844483.0123, NFrames: 0.0
# Time: 83844516.3457, NFrames: 0.0
# Time: 83844549.679, NFrames: 0.0
# Time: 83844583.0123, NFrames: 0.0
# ...

# %% [markdown]
# ### <span style="font-size: 0.9em;">🟧</span> **Save video file**

# %%
cv2.VideoWriter?
# Out:
# Init signature: cv2.VideoWriter(self, /, *args, **kwargs)
# Docstring:      <no docstring>
# File:           c:\users\howsam\appdata\local\anaconda3\envs\torchv2\lib\site-packages\cv2\__init__.py
# Type:           type
# Subclasses:

# %%
fourcc = cv2.VideoWriter_fourcc("H", "2", "6", "4")
out = cv2.VideoWriter("results/teqball-output.mp4", fourcc, fps, (width, height), isColor)

# %%
fourcc = cv2.VideoWriter_fourcc("M", "J", "P", "G")
out = cv2.VideoWriter("results/teqball-output.avi", fourcc)

# %%
fourcc = cv2.VideoWriter_fourcc("R", "A", "W", " ")
out = cv2.VideoWriter("results/teqball-output.avi", fourcc)

# %%
cap = cv2.VideoCapture("video/teqball.mp4")

# fourcc = cv2.VideoWriter_fourcc("H", "2", "6", "4")
# out = cv2.VideoWriter("results/teqball-output.mp4", fourcc, 20, (1280, 720), isColor=False)

# fourcc = cv2.VideoWriter_fourcc("M", "J", "P", "G")
# out = cv2.VideoWriter("results/teqball-output.avi", fourcc, 20, (1280, 720), isColor=False)

fourcc = cv2.VideoWriter_fourcc("R", "A", "W", " ")
out = cv2.VideoWriter("results/teqball-output.avi", fourcc, 20, (1280, 720), isColor=False)

print(f"Height: {cap.get(cv2.CAP_PROP_FRAME_HEIGHT)}, Width: {cap.get(cv2.CAP_PROP_FRAME_WIDTH)}")
print(f"Frame Count: {cap.get(cv2.CAP_PROP_FRAME_COUNT)}")
print(f"FPS: {cap.get(cv2.CAP_PROP_FPS)}")


while cap.isOpened():
    ret, frame = cap.read()

    if not ret:
        break

    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    cv2.imshow("Frame", frame)

    key = cv2.waitKey(1)
    if key == ord("q"):
        break
    
    out.write(frame)

    print(f'Time: {cap.get(cv2.CAP_PROP_POS_MSEC)}, NFrames: {cap.get(cv2.CAP_PROP_POS_FRAMES)}')
    
cv2.destroyAllWindows()
cap.release()
out.release()
# Out:
# Height: 720.0, Width: 1280.0
# Frame Count: 578.0
# FPS: 25.0
# Time: 0.0, NFrames: 1.0
# Time: 40.0, NFrames: 2.0
# Time: 80.0, NFrames: 3.0
# Time: 120.0, NFrames: 4.0
# Time: 160.0, NFrames: 5.0
# Time: 200.0, NFrames: 6.0
# Time: 240.0, NFrames: 7.0
# Time: 280.0, NFrames: 8.0
# Time: 320.0, NFrames: 9.0
# Time: 360.0, NFrames: 10.0
# Time: 400.0, NFrames: 11.0
# Time: 440.0, NFrames: 12.0
# Time: 480.0, NFrames: 13.0
# Time: 520.0, NFrames: 14.0
# Time: 560.0, NFrames: 15.0
# Time: 600.0, NFrames: 16.0
# Time: 640.0, NFrames: 17.0
# Time: 680.0, NFrames: 18.0
# Time: 720.0, NFrames: 19.0
# Time: 760.0, NFrames: 20.0
# Time: 800.0, NFrames: 21.0
# Time: 840.0, NFrames: 22.0
# Time: 880.0, NFrames: 23.0
# Time: 920.0, NFrames: 24.0
# Time: 960.0, NFrames: 25.0
# Time: 1000.0, NFrames: 26.0
# Time: 1040.0, NFrames: 27.0
# Time: 1080.0, NFrames: 28.0
# Time: 1120.0, NFrames: 29.0
# Time: 1160.0, NFrames: 30.0
# Time: 1200.0, NFrames: 31.0
# Time: 1240.0, NFrames: 32.0
# ...

# %% [markdown]
# ### <span style="font-size: 0.9em;">🟧</span> **More on `cv2.VideoCapture()`**

# %% [markdown]
# #### <span style="font-size: 0.9em;">🟨</span> **Get video from url**

# %%
cap = cv2.VideoCapture("https://dl.howsam.org/opencv/data/table-tennis.mp4")

print(f"Height: {cap.get(cv2.CAP_PROP_FRAME_HEIGHT)}, Width: {cap.get(cv2.CAP_PROP_FRAME_WIDTH)}")
print(f"Frame Count: {cap.get(cv2.CAP_PROP_FRAME_COUNT)}")
print(f"FPS: {cap.get(cv2.CAP_PROP_FPS)}")


while cap.isOpened():
    ret, frame = cap.read()

    if not ret:
        break

    cv2.imshow("Frame", frame)

    key = cv2.waitKey(40)
    if key == ord("q"):
        break
    
cv2.destroyAllWindows()
cap.release()
# Out:
# Height: 1280.0, Width: 720.0
# Frame Count: 1617.0
# FPS: 30.0

# %% [markdown]
# #### <span style="font-size: 0.9em;">🟨</span> **Reading an Image Sequence**

# %%
cap = cv2.VideoCapture("video/video_frames/%08d.jpg")
cap.read()
# Out:
# (True,
#  array([[[137, 139, 137],
#          [137, 139, 137],
#          [137, 139, 137],
#          ...,
#          [210, 144, 105],
#          [211, 145, 106],
#          [211, 145, 106]],
#
#         [[137, 139, 137],
#          [137, 139, 137],
#          [137, 139, 137],
#          ...,
#          [210, 144, 105],
#          [211, 145, 106],
#          [211, 145, 106]],
#
#         [[139, 139, 137],
#          [139, 139, 137],
#          [139, 139, 137],
#          ...,
#          [211, 145, 106],
#          [211, 145, 106],
#          [211, 145, 106]],
#
#         ...,
#
#         [[ 97,  80,  71],
#          [ 82,  65,  56],
#          [ 65,  48,  39],
#          ...,
#          [207, 156, 117],
#          [207, 156, 117],
#          [207, 156, 117]],
#
#         [[ 82,  68,  60],
#          [ 71,  57,  49],
#          [ 57,  43,  35],
#          ...,
#          [195, 155, 124],
#          [195, 155, 124],
#          [195, 155, 124]],
#
#         [[ 76,  62,  54],
# ...

# %%
for i in range(100):
    print(f"{i:08d}")
# Out:
# 00000000
# 00000001
# 00000002
# 00000003
# 00000004
# 00000005
# 00000006
# 00000007
# 00000008
# 00000009
# 00000010
# 00000011
# 00000012
# 00000013
# 00000014
# 00000015
# 00000016
# 00000017
# 00000018
# 00000019
# 00000020
# 00000021
# 00000022
# 00000023
# 00000024
# 00000025
# 00000026
# 00000027
# 00000028
# 00000029
# 00000030
# 00000031
# 00000032
# 00000033
# 00000034
# 00000035
# 00000036
# 00000037
# 00000038
# 00000039
# 00000040
# 00000041
# 00000042
# 00000043
# 00000044
# 00000045
# 00000046
# 00000047
# 00000048
# 00000049
# 00000050
# 00000051
# 00000052
# 00000053
# 00000054
# 00000055
# 00000056
# 00000057
# 00000058
# 00000059
# 00000060
# 00000061
# 00000062
# 00000063
# 00000064
# 00000065
# 00000066
# 00000067
# 00000068
# 00000069
# 00000070
# 00000071
# 00000072
# 00000073
# 00000074
# 00000075
# 00000076
# 00000077
# 00000078
# 00000079
# 00000080
# 00000081
# 00000082
# 00000083
# 00000084
# 00000085
# 00000086
# 00000087
# 00000088
# 00000089
# ...

# %%
cap = cv2.VideoCapture("video/video_frames/%8d.jpg")

print(f"Height: {cap.get(cv2.CAP_PROP_FRAME_HEIGHT)}, Width: {cap.get(cv2.CAP_PROP_FRAME_WIDTH)}")
print(f"Frame Count: {cap.get(cv2.CAP_PROP_FRAME_COUNT)}")
print(f"FPS: {cap.get(cv2.CAP_PROP_FPS)}")


while cap.isOpened():
    ret, frame = cap.read()

    if not ret:
        break

    cv2.imshow("Frame", frame)

    key = cv2.waitKey(40)
    if key == ord("q"):
        break
    
cv2.destroyAllWindows()
cap.release()
# Out:
# Height: 600.0, Width: 800.0
# Frame Count: 102.0
# FPS: 25.0

# %% [markdown]
# #### <span style="font-size: 0.9em;">🟨</span> **IP camera**

# %% [markdown]
# ![image.png](attachment:664c0e19-1a2b-423c-8d17-d975ae646503.png)

# %%
cap = cv2.VideoCapture("rtsp://192.168.1.64/1")
cap.read()

# %%
cap = cv2.VideoCapture("rtsp://username:password@192.168.1.64/1")
cap.read()

# %% [markdown]
# #### <span style="font-size: 0.9em;">🟨</span> **Set frame position**

# %%
cap = cv2.VideoCapture("video/table-tennis.mp4")

cap.set(cv2.CAP_PROP_POS_FRAMES, 1000)

print(f"Height: {cap.get(cv2.CAP_PROP_FRAME_HEIGHT)}, Width: {cap.get(cv2.CAP_PROP_FRAME_WIDTH)}")
print(f"Frame Count: {cap.get(cv2.CAP_PROP_FRAME_COUNT)}")
print(f"FPS: {cap.get(cv2.CAP_PROP_FPS)}")

while cap.isOpened():
    ret, frame = cap.read()

    if not ret:
        break

    cv2.imshow("Frame", frame)

    key = cv2.waitKey(40)
    if key == ord("q"):
        break
    
cv2.destroyAllWindows()
cap.release()
# Out:
# Height: 1280.0, Width: 720.0
# Frame Count: 1617.0
# FPS: 30.0

# %% [markdown]
# #### <span style="font-size: 0.9em;">🟨</span> **Other `cv2.VideoCapture()` methods**

# %%
cap.
